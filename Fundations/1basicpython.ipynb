# %% [markdown]
# #### Basic of Python
# - various data types in python
# - Variables
# - variables assignment in python
# - printing format in python

# %% [markdown]
# ### datatypes
#  - stings
#  - variables
#  - print

# %%
2+3
# Out:
# 5

# %%
5*5
# Out:
# 25

# %%
2+2
# Out:
# 4

# %%
5*5
# Out:
# 25

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
100**2
# Out:
# 10000

# %%
10 * "maha"
# Out:
# 'mahamahamahamahamahamahamahamahamahamaha'

# %% [markdown]
# ### Data types

# %%
type(10.0)
# Out:
# float

# %% [markdown]
# #### Strings

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
'world'
# Out:
# 'world'

# %%
"hello" + "world"
# Out:
# 'helloworld'

# %%
"hello" +" " +"world 123"
# Out:
# 'hello world 123'

# %%
type("maha 123")
# Out:
# str

# %% [markdown]
# #### Variables Assignment

# %%
# syntax 
# variable_name = value
a = 30
b = 50

c= a + b 
print(c)
# Out:
# 80

# %%
type(c)
# Out:
# int

# %%
a=20
b=30

# %%
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)## mathmatical operations  will be performed
# Out:
# -10
# 600
# 0.6666666666666666
# 20
# 1073741824000000000000000000000000000000

# %%
print("hell0")
# Out:
# hell0

# %%
first_name = "maha"
last_name = "AIpro"

# %%
print(first_name + " " + last_name)
# Out:
# maha AIpro

# %%
print( "my first name is {} and last name is {}".format(last_name,first_name) )
# Out:
# my first name is AIpro and last name is maha

# %%
print("my first name is {first} and Last name is {last}".format(last=last_name, first=first_name) )
# Out:
# my first name is maha and Last name is AIpro

# %%
print("my first name is {last_name} and my last name is {first_name}".format(first_name=first_name, last_name=last_name))
# Out:
# my first name is AIpro and my last name is maha
