# %%
import pandas as pd
import numpy as np

# %%
data= '{"Empname":"maha","email":"maha@gmail.com","jobprofile":[{"jobtitle1":"TeanLead","jobtitle2":"AIML"}]}'

# %%
df= pd.read_json(data)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4000\3603303076.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df= pd.read_json(data)
